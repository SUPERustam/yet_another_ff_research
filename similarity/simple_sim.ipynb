# %% [markdown]
# https://www.alibabacloud.com/blog/similarity-algorithms-effective-similarity-search-in-postgresql_595785#:~:text=You%20can%20also%20calculate%20the,similarity%20based%20on%20the%20tokens
#
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
#
# Examples by author:
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %%
import numpy as np
from PIL import Image

# %% [markdown]
# ImgSmlr – similar images search for PostgreSQL: https://github.com/postgrespro/imgsmlr
